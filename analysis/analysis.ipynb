# %%
import os
import MDAnalysis as mda
from nmrdfrommd import NMRD

from utilities import save_result, get_git_repo_path

git_path = get_git_repo_path()
data_dir = os.path.join(git_path, "data")
topology_file = os.path.join(data_dir, "production-hyd.lammpstrj")
trajectory_file = os.path.join(data_dir, "dump.xtc")

u = mda.Universe(topology_file, trajectory_file)
H_PEG = u.select_atoms("type 3 5")
H_H2O = u.select_atoms("type 7")
H_ALL = H_PEG + H_H2O
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 12
#      10 trajectory_file = os.path.join(data_dir, "dump.xtc")
# ---> 12 u = mda.Universe(topology_file, trajectory_file)
#      13 H_PEG = u.select_atoms("type 3 5")
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:417, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, context, to_guess, force_guess, in_memory_step, *coordinates, **kwargs)
#     416     self.filename = _check_file_like(topology)
# --> 417     topology = _topology_from_file_like(self.filename,
#     418                                         topology_format=topology_format,
#     419                                         **kwargs)
#     421 if topology is not None:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:121, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     118 if (err.errno is not None and
#     119     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120     # Runs if the error is propagated due to no permission / file not found
# --> 121     raise sys.exc_info()[1] from err
#     122 else:
#     123     # Runs when the parser fails
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:113, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     112     with parser(topology_file) as p:
# --> 113         topology = p.parse(**kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:287, in DATAParser.parse(self, **kwargs)
#     285     self.style_dict = None
# --> 287 head, sects = self.grab_datafile()
#     289 try:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:217, in DATAParser.grab_datafile(self)
#     210 """Split a data file into dict of header and sections
#     211
#     212 Returns
#    (...)
#     215 sections - dict of section name: content
#     216 """
# --> 217 f = list(self.iterdata())
#     219 starts = [i for i, line in enumerate(f) if line.split()[0] in SECTIONS]
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:203, in DATAParser.iterdata(self)
#     202 def iterdata(self):
# --> 203     with openany(self.filename) as f:
#     204         for line in f:
#
# File /usr/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:326, in openany(datasource, mode, reset)
#     284 """Context manager for :func:`anyopen`.
#     285
#     286 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     324 :func:`anyopen`
#     325 """
# --> 326 stream = anyopen(datasource, mode=mode, reset=reset)
#     327 try:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:408, in anyopen(datasource, mode, reset)
#     407 openfunc = read_handlers[ext]
# --> 408 stream = _get_stream(datasource, openfunc, mode=mode)
#     409 if stream is not None:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:468, in _get_stream(filename, openfunction, mode)
#     467 if errno.errorcode[err.errno] in ["ENOENT", "EACCES"]:
# --> 468     raise sys.exc_info()[1] from err
#     469 return None
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:462, in _get_stream(filename, openfunction, mode)
#     461 try:
# --> 462     stream = openfunction(filename, mode=mode)
#     463 except (IOError, OSError) as err:
#     464     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     465     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     466     # either the file isn't there or the permissions don't allow access.
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:540, in bz2_pickle_open(name, mode)
#     539 bz_mode = mode.replace("t", "")
# --> 540 binary_file = BZ2Picklable(name, bz_mode)
#     541 if "t" in mode:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:309, in BZ2Picklable.__init__(self, name, mode)
#     308 self._bz_mode = mode
# --> 309 super().__init__(name, mode)
#
# File /usr/lib/python3.12/bz2.py:81, in BZ2File.__init__(self, filename, mode, compresslevel)
#      80 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 81     self._fp = _builtin_open(filename, mode)
#      82     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/simon/Git/NMR/dataset-peg-water-mixture/data/topology.data'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 12
#      10 trajectory_file = os.path.join(data_dir, "dump.xtc")
# ---> 12 u = mda.Universe(topology_file, trajectory_file)
#      13 H_PEG = u.select_atoms("type 3 5")
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:417, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, context, to_guess, force_guess, in_memory_step, *coordinates, **kwargs)
#     416     self.filename = _check_file_like(topology)
# --> 417     topology = _topology_from_file_like(self.filename,
#     418                                         topology_format=topology_format,
#     419                                         **kwargs)
#     421 if topology is not None:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:121, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     118 if (err.errno is not None and
#     119     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120     # Runs if the error is propagated due to no permission / file not found
# --> 121     raise sys.exc_info()[1] from err
#     122 else:
#     123     # Runs when the parser fails
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:113, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     112     with parser(topology_file) as p:
# --> 113         topology = p.parse(**kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:287, in DATAParser.parse(self, **kwargs)
#     285     self.style_dict = None
# --> 287 head, sects = self.grab_datafile()
#     289 try:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:217, in DATAParser.grab_datafile(self)
#     210 """Split a data file into dict of header and sections
#     211
#     212 Returns
#    (...)
#     215 sections - dict of section name: content
#     216 """
# --> 217 f = list(self.iterdata())
#     219 starts = [i for i, line in enumerate(f) if line.split()[0] in SECTIONS]
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:203, in DATAParser.iterdata(self)
#     202 def iterdata(self):
# --> 203     with openany(self.filename) as f:
#     204         for line in f:
#
# File /usr/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:326, in openany(datasource, mode, reset)
#     284 """Context manager for :func:`anyopen`.
#     285
#     286 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     324 :func:`anyopen`
#     325 """
# --> 326 stream = anyopen(datasource, mode=mode, reset=reset)
#     327 try:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:408, in anyopen(datasource, mode, reset)
#     407 openfunc = read_handlers[ext]
# --> 408 stream = _get_stream(datasource, openfunc, mode=mode)
#     409 if stream is not None:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:468, in _get_stream(filename, openfunction, mode)
#     467 if errno.errorcode[err.errno] in ["ENOENT", "EACCES"]:
# --> 468     raise sys.exc_info()[1] from err
#     469 return None
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:462, in _get_stream(filename, openfunction, mode)
#     461 try:
# --> 462     stream = openfunction(filename, mode=mode)
#     463 except (IOError, OSError) as err:
#     464     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     465     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     466     # either the file isn't there or the permissions don't allow access.
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:540, in bz2_pickle_open(name, mode)
#     539 bz_mode = mode.replace("t", "")
# --> 540 binary_file = BZ2Picklable(name, bz_mode)
#     541 if "t" in mode:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:309, in BZ2Picklable.__init__(self, name, mode)
#     308 self._bz_mode = mode
# --> 309 super().__init__(name, mode)
#
# File /usr/lib/python3.12/bz2.py:81, in BZ2File.__init__(self, filename, mode, compresslevel)
#      80 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 81     self._fp = _builtin_open(filename, mode)
#      82     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/simon/Git/NMR/dataset-peg-water-mixture/data/topology.data'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 topology_file = os.path.join(data_dir, "topology.data")
#      10 trajectory_file = os.path.join(data_dir, "dump.xtc")
# ---> 12 u = mda.Universe(topology_file, trajectory_file)
#      13 H_PEG = u.select_atoms("type 3 5")
#      14 H_H2O = u.select_atoms("type 7")
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:417, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, context, to_guess, force_guess, in_memory_step, *coordinates, **kwargs)
#     415 if not isinstance(topology, Topology) and not topology is None:
#     416     self.filename = _check_file_like(topology)
# --> 417     topology = _topology_from_file_like(self.filename,
#     418                                         topology_format=topology_format,
#     419                                         **kwargs)
#     421 if topology is not None:
#     422     self._topology = topology
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:121, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#     118     if (err.errno is not None and
#     119         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120         # Runs if the error is propagated due to no permission / file not found
# --> 121         raise sys.exc_info()[1] from err
#     122     else:
#     123         # Runs when the parser fails
#     124         raise IOError("Failed to load from the topology file {0}"
#     125                         " with parser {1}.\n"
#     126                         "Error: {2}".format(topology_file, parser, err))
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/core/universe.py:113, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     111 try:
#     112     with parser(topology_file) as p:
# --> 113         topology = p.parse(**kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#     118     if (err.errno is not None and
#     119         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120         # Runs if the error is propagated due to no permission / file not found
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:287, in DATAParser.parse(self, **kwargs)
#     284 except KeyError:
#     285     self.style_dict = None
# --> 287 head, sects = self.grab_datafile()
#     289 try:
#     290     masses = self._parse_masses(sects["Masses"])
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:217, in DATAParser.grab_datafile(self)
#     209 def grab_datafile(self):
#     210     """Split a data file into dict of header and sections
#     211
#     212     Returns
#    (...)
#     215     sections - dict of section name: content
#     216     """
# --> 217     f = list(self.iterdata())
#     219     starts = [i for i, line in enumerate(f) if line.split()[0] in SECTIONS]
#     220     starts += [None]
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/topology/LAMMPSParser.py:203, in DATAParser.iterdata(self)
#     202 def iterdata(self):
# --> 203     with openany(self.filename) as f:
#     204         for line in f:
#     205             line = line.partition("#")[0].strip()
#
# File /usr/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:326, in openany(datasource, mode, reset)
#     282 @contextmanager
#     283 def openany(datasource, mode="rt", reset=True):
#     284     """Context manager for :func:`anyopen`.
#     285
#     286     Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     324     :func:`anyopen`
#     325     """
# --> 326     stream = anyopen(datasource, mode=mode, reset=reset)
#     327     try:
#     328         yield stream
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:408, in anyopen(datasource, mode, reset)
#     406 for ext in ("bz2", "gz", ""):  # file == '' should be last
#     407     openfunc = read_handlers[ext]
# --> 408     stream = _get_stream(datasource, openfunc, mode=mode)
#     409     if stream is not None:
#     410         break
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:468, in _get_stream(filename, openfunction, mode)
#     463 except (IOError, OSError) as err:
#     464     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     465     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     466     # either the file isn't there or the permissions don't allow access.
#     467     if errno.errorcode[err.errno] in ["ENOENT", "EACCES"]:
# --> 468         raise sys.exc_info()[1] from err
#     469     return None
#     470 if mode.startswith("r"):
#     471     # additional check for reading (eg can we uncompress) --- is this needed?
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/util.py:462, in _get_stream(filename, openfunction, mode)
#     460 """Return open stream if *filename* can be opened with *openfunction* or else ``None``."""
#     461 try:
# --> 462     stream = openfunction(filename, mode=mode)
#     463 except (IOError, OSError) as err:
#     464     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     465     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     466     # either the file isn't there or the permissions don't allow access.
#     467     if errno.errorcode[err.errno] in ["ENOENT", "EACCES"]:
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:540, in bz2_pickle_open(name, mode)
#     536     raise ValueError(
#     537         "Only read mode ('r', 'rt', 'rb') " "files can be pickled."
#     538     )
#     539 bz_mode = mode.replace("t", "")
# --> 540 binary_file = BZ2Picklable(name, bz_mode)
#     541 if "t" in mode:
#     542     return TextIOPicklable(binary_file)
#
# File ~/.local/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:309, in BZ2Picklable.__init__(self, name, mode)
#     307 def __init__(self, name, mode="rb"):
#     308     self._bz_mode = mode
# --> 309     super().__init__(name, mode)
#
# File /usr/lib/python3.12/bz2.py:81, in BZ2File.__init__(self, filename, mode, compresslevel)
#      78     raise ValueError("Invalid mode: %r" % (mode,))
#      80 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 81     self._fp = _builtin_open(filename, mode)
#      82     self._closefp = True
#      83     self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/simon/Git/NMR/dataset-peg-water-mixture/data/topology.data'
